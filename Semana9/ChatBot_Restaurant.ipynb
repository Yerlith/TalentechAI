# %% [markdown]
# # ChatBot uitlizando OpenAI
#
# Para obtener una clave de API de OpenAI, sigue estos pasos:
#
# * Crear o acceer a una cuenta en OpenAI:
#
# Ve al sitio web de OpenAI.
# Haz clic en "Sign Up" para crear una nueva cuenta o "Log In" si ya tienes una.
#
# * Acceder a la sección de API:
#
# Una vez iniciada la sesión, dirígete al Dashboard de la API de OpenAI.
#
# * Generar una nueva clave de API:
#
# En el dashboard, busca la sección de "API Keys".
# Haz clic en "Create new secret key".
# Aparecerá un cuadro de diálogo con tu nueva clave de API.
#
# * Configurar la clave en tu código:
#
# Utiliza la clave generada en tu código para autenticarte con la API de OpenAI.

# %%
# !pip uninstall openai -y
# Out:
# WARNING: Skipping openai as it is not installed.

# %%
# !pip install openai==1.0.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.6 MB/s eta 0:00:00
# ...

# %%
import openai

# Verificar la versión de la biblioteca OpenAI
print(openai.__version__)
# Out:
# 1.0.0

# %%
# !pip install openai==0.28
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 5.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.0.0
#     Uninstalling openai-1.0.0:
#       Successfully uninstalled openai-1.0.0
# ...

# %%
import openai
import time

# Configura tu clave de API de OpenAI
openai.api_key = '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' #'TU_CLAVE_DE_API_AQUÍ'

def chatbot(prompt):
    try:
        response = openai.Completion.create(
            model="gpt-3.5-turbo",
            prompt=prompt,
            max_tokens=150,
            temperature=0.7
        )
        return response.choices[0].text.strip()
    except openai.error.RateLimitError:
        print("Se ha excedido el límite de tasa. Por favor, espera un momento y vuelve a intentarlo.")
        time.sleep(60)  # Espera 60 segundos antes de reintentar
        return chatbot(prompt)

# Ejemplo de uso del chatbot
while True:
    user_input = input("Tú: ")
    if user_input.lower() in ['salir', 'exit']:
        print("Chatbot: ¡Adiós!")
        break
    response = chatbot(user_input)
    print(f"Chatbot: {response}")
# Out:
# Tú: Hola
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-7e2f460c7388> in chatbot(prompt)
#       8     try:
# ----> 9         response = openai.Completion.create(
#      10             model="gpt-3.5-turbo",
#
# AttributeError: module 'openai' has no attribute 'Completion'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-7e2f460c7388> in <cell line: 22>()
#      25         print("Chatbot: ¡Adiós!")
#      26         break
# ---> 27     response = chatbot(user_input)
#      28     print(f"Chatbot: {response}")
#
# <ipython-input-5-7e2f460c7388> in chatbot(prompt)
#      14         )
#      15         return response.choices[0].text.strip()
# ---> 16     except openai.error.RateLimitError:
# ...

# %%
import openai

# Configura tu clave de API de OpenAI
openai.api_key = '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' #'TU_CLAVE_DE_API_AQUÍ'

def chatbot(prompt):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message['content'].strip()

# Ejemplo de uso del chatbot
while True:
    user_input = input("Tú: ")
    if user_input.lower() in ['salir', 'exit']:
        print("Chatbot: ¡Adiós!")
        break
    response = chatbot(user_input)
    print(f"Chatbot: {response}")
# Out:
# Tú: Hola
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-3-35446328498c> in <cell line: 17>()
#      20         print("Chatbot: ¡Adiós!")
#      21         break
# ---> 22     response = chatbot(user_input)
#      23     print(f"Chatbot: {response}")
#
# <ipython-input-3-35446328498c> in chatbot(prompt)
#       5
#       6 def chatbot(prompt):
# ----> 7     response = openai.ChatCompletion.create(
#       8         model="gpt-3.5-turbo",
#       9         messages=[
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ...
